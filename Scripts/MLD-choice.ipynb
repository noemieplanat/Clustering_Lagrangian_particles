# %%
import xarray as xr
import numpy as np
import pylab as plt
import cartopy.crs as ccrs
import cmocean
import copy as cp
from scipy.interpolate import griddata, interp1d
import pickle
import glob
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
from matplotlib.cm import get_cmap
import cartopy as cr
import matplotlib.cm as cm
from datetime import datetime as dtime
import matplotlib.colors as colors

# %%
ds = xr.open_dataset('/storage/nplanat/Glorys12_ORCA_journalier/Glorys12_Grid2D_1993_01_01.nc')

# %%
f = plt.figure(figsize = (16, 5))
ax = f.add_subplot(1,3,1, projection = ccrs.NorthPolarStereo())
ax.coastlines()
ax.gridlines()
ax.set_extent([-180, 180, 65, 90], crs=ccrs.PlateCarree())
ds.somxl010.isel(time_counter=0).plot.pcolormesh(vmax = 100, x = 'nav_lon', y = 'nav_lat', transform = ccrs.PlateCarree())

ax = f.add_subplot(1,3,2, projection = ccrs.NorthPolarStereo())
ax.coastlines()
ax.gridlines()
ax.set_extent([-180, 180, 65, 90], crs=ccrs.PlateCarree())
ds.somxlavt.isel(time_counter=0).plot.pcolormesh(vmax = 100, x = 'nav_lon', y = 'nav_lat', transform = ccrs.PlateCarree())

ax = f.add_subplot(1,3,3, projection = ccrs.NorthPolarStereo())
ax.coastlines()
ax.gridlines()
ax.set_extent([-180, 180, 65, 90], crs=ccrs.PlateCarree())
ds.somxlt02.isel(time_counter=0).plot.pcolormesh(vmax = 100, x = 'nav_lon', y = 'nav_lat', transform = ccrs.PlateCarree())
# Out:
# /storage/nplanat/MINICONDA/envs/analysis/lib/python3.9/site-packages/cartopy/mpl/geoaxes.py:1597: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   X, Y, C, shading = self._pcolorargs('pcolormesh', *args,

# %%
f = plt.figure(figsize = (7, 7))
ax = f.add_subplot(1,1,1, projection = ccrs.NorthPolarStereo())
ax.coastlines()
ax.gridlines()
ax.set_extent([-200, -90, 65, 90], crs=ccrs.PlateCarree())
ds.somxl010.isel(time_counter=0).plot.pcolormesh(vmax = 60, x = 'nav_lon', y = 'nav_lat', transform = ccrs.PlateCarree())

# %%
f = plt.figure(figsize =(7, 7))
ax = f.add_subplot(1,1,1, projection = ccrs.NorthPolarStereo())
ax.coastlines()
ax.gridlines()
ax.set_extent([-180, 180, 65, 90], crs=ccrs.PlateCarree())
(ds.somxl010-ds.somxlavt).isel(time_counter=0).plot.pcolormesh(vmax = 5, x = 'nav_lon', y = 'nav_lat', transform = ccrs.PlateCarree())
# Out:
# /storage/nplanat/MINICONDA/envs/analysis/lib/python3.9/site-packages/cartopy/mpl/geoaxes.py:1597: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   X, Y, C, shading = self._pcolorargs('pcolormesh', *args,
